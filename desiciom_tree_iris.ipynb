# %% [markdown]
# <a href="https://colab.research.google.com/github/JasmineJames25/Machine-Learning-Projects/blob/main/desiciom_tree_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.drop(columns='Id',inplace=True)

# %%
x=df.iloc[:,:-1]

# %%
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
y_test
# Out:
# 73     Iris-versicolor
# 18         Iris-setosa
# 118     Iris-virginica
# 78     Iris-versicolor
# 76     Iris-versicolor
# 31         Iris-setosa
# 64     Iris-versicolor
# 141     Iris-virginica
# 68     Iris-versicolor
# 82     Iris-versicolor
# 110     Iris-virginica
# 12         Iris-setosa
# 36         Iris-setosa
# 9          Iris-setosa
# 19         Iris-setosa
# 56     Iris-versicolor
# 104     Iris-virginica
# 69     Iris-versicolor
# 55     Iris-versicolor
# 132     Iris-virginica
# 29         Iris-setosa
# 127     Iris-virginica
# 26         Iris-setosa
# 128     Iris-virginica
# 131     Iris-virginica
# 145     Iris-virginica
# 108     Iris-virginica
# 143     Iris-virginica
# 45         Iris-setosa
# 30         Iris-setosa
# 22         Iris-setosa
# 15         Iris-setosa
# 65     Iris-versicolor
# 11         Iris-setosa
# 42         Iris-setosa
# 146     Iris-virginica
# 51     Iris-versicolor
# 27         Iris-setosa
# 4          Iris-setosa
# 32         Iris-setosa
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
scaler.fit(x_train)
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)
x_train
# Out:
# array([[-0.4134164 , -1.46440146, -0.10014569, -0.32149987],
#        [ 0.55122187, -0.49582097,  0.71771076,  0.35364985],
#        [ 0.67180165,  0.2306144 ,  0.95138404,  0.75873969],
#        [ 0.91296121, -0.01153072,  0.30878254,  0.21861991],
#        [ 1.63643991,  1.44134002,  1.30189395,  1.7039493 ],
#        [-0.17225683, -0.25367584,  0.1919459 ,  0.08358997],
#        [ 2.11875905, -0.01153072,  1.59398554,  1.16382952],
#        [-0.29283662, -0.01153072,  0.36720086,  0.35364985],
#        [-0.89573553,  1.19919489, -1.443767  , -1.40173942],
#        [ 2.23933883, -0.49582097,  1.65240385,  1.02879957],
#        [-0.05167705, -0.73796609,  0.13352758, -0.32149987],
#        [-0.77515575,  0.95704977, -1.443767  , -1.40173942],
#        [-1.01631531,  1.19919489, -1.50218532, -1.26670948],
#        [-0.89573553,  1.92563026, -1.15167541, -1.13167953],
#        [-1.01631531, -2.43298195, -0.21698232, -0.32149987],
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
dec=DecisionTreeClassifier(criterion='entropy')
dec.fit(x_train,y_train)
y_pred=dec.predict(x_test)
y_pred
# Out:
# array(['Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa'], dtype=object)

# %%
#model creation using decision tree
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
tree.plot_tree(dec,feature_names=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm','Species'])
# Out:
# [Text(0.5, 0.9166666666666666, 'PetalWidthCm <= -0.592\nentropy = 1.58\nsamples = 105\nvalue = [31, 37, 37]'),
#  Text(0.4230769230769231, 0.75, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'PetalWidthCm <= 0.691\nentropy = 1.0\nsamples = 74\nvalue = [0, 37, 37]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'PetalLengthCm <= 0.63\nentropy = 0.535\nsamples = 41\nvalue = [0, 36, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'PetalWidthCm <= 0.489\nentropy = 0.187\nsamples = 35\nvalue = [0, 34, 1]'),
#  Text(0.07692307692307693, 0.25, 'entropy = 0.0\nsamples = 34\nvalue = [0, 34, 0]'),
#  Text(0.23076923076923078, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'PetalWidthCm <= 0.421\nentropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
# ...

# %%
#performence evaluation
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,accuracy_score,classification_report
result=confusion_matrix(y_test,y_pred)
DT_score=accuracy_score(y_test,y_pred)
report=classification_report(y_test,y_pred)
label=['Iris-versicolor',' Iris-setosa','Iris-virginica']
cmd=ConfusionMatrixDisplay(result,display_labels=label)
cmd.plot()

# %%
# print('confusion matrix:',result)
result
# Out:
# array([[19,  0,  0],
#        [ 0,  7,  6],
#        [ 0,  0, 13]])

# %%
print('accuracy score of iris using decision tree classifier:',DT_score)
# Out:
# accuracy score of iris using decision tree classifier: 0.8666666666666667

# %%
#classification report
print(report)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      0.54      0.70        13
#  Iris-virginica       0.68      1.00      0.81        13
#
#        accuracy                           0.87        45
#       macro avg       0.89      0.85      0.84        45
#    weighted avg       0.91      0.87      0.86        45

# %%
#Modelcreation using Randomforest classifier
from sklearn.ensemble import RandomForestClassifier
rm=RandomForestClassifier(n_estimators=10,criterion='entropy')
rm.fit(x_train,y_train)
y_pred=rm.predict(x_test)
y_pred
# Out:
# array(['Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,accuracy_score,classification_report
result=confusion_matrix(y_test,y_pred)
RF_score=accuracy_score(y_test,y_pred)
report=classification_report(y_test,y_pred)
label=['Iris-versicolor',' Iris-setosa','Iris-virginica']

# %%
print('Accuracy score of Iris using RandomForest classifier:',RF_score)
# Out:
# Accuracy score of Iris using RandomForest classifier: 0.9333333333333333

# %% [markdown]
# *   **Decision Tree Classifier Accuracy: 0.867**
# *   **Random Forest Classifier Accuracy: 0.933**
#
# >Based on the comparison, the Random Forest classifier achieved a higher accuracy score (0.933) compared to the Decision Tree classifier (0.867) for the Iris dataset. This suggests that the Random Forest model performed better in this scenario.
